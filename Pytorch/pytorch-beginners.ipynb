# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Credits : https://youtu.be/c36lUUr864M

# %%
# Import torch library 
import torch

# %%
# Connect to the GPU in Accelerator 
torch.cuda.is_available()

# %%
# Creating an Empyt tensor 
x = torch.empty(1)
x

# %%
# Creating a 1d tensor - Vector
x =torch.empty(3)
x

# %%
# Crate a 2d matrix
x= torch.empty(2,3)
x

# %%
# create a tensor from random numbers
x =torch.rand(2,2)
x

# %%
# create a tensor contains zeros 
x =torch.zeros(2,2)
x

# %%
# create a tensor contains ones
x =torch.ones(2,2)
x

# %%
# Exsplore the datatype
x.dtype

# %%
# create a tensor of dtype int 
x =torch.ones(2,2,dtype=torch.int)
x

# %%
# create a tensor of dtype double 
x =torch.ones(2,2,dtype=torch.double)
x

# %%
# to get the size of the tensor 
x.size()

# %%
# creating a tensor out of python list 
import random
p_list =  [random.randrange(100) for i in range(10)]
x = torch.tensor(p_list)
print(x)
print(x.dtype)
print(x.size())

# %%
# Arithmetc operation addition between tensors

x=torch.rand(2,2)
y=torch.rand(2,2)
print(x)
print(y)
z= x+y
z

# %%
# other way to do the same 
z = torch.add(x,y)
z

# %%
# Inplace addition 
y.add_(x)

# %% [markdown]
# 👓The varbale y is altered , the method ends with _ does the inplace change

# %%
# Same way we can do  multiplication and division element wise

# %%
# Slicing and indexing

x = torch.rand(3,4)
print(x)
x[:,1]  # Requesting all rows and first column

# %%
x[1,:] # Requesting all columns and first row

# %%
# Indexing
print(x[1,1] ) # comes as a tensor 

# to get the real value 
x[1,1].item()

# %%
# Reshape a tensor

x=torch.rand(4,4)
y=x.view(16)
y

# %%
z=x.view(8,2)
z

# %%
# If you are not sure about any of the dimension you can put 
z=x.view(8,-1)  # The shape is automatically picked if input -1
z

# %%
# you will encounter an error , because the total elements must add upto 16 where as 6*real_number !=16
z= x.view(6,-1)
z

# %%
# Converting a tensor to numpy arrray
#import numpy as np
a =  torch.ones(3,4)
b=  a.numpy()
print(b)

# %%
# Lets verify the ids 
print(hex(id(a)))
print(hex(id(b)))

# these variable are stored in different memory location since it is in GPU 
# In CPU both variables wil be in same locqation

# %%
a.add_(1)

# %%
b

# %%
if torch.cuda.is_available():
    print('CUDA found')
    # Creating tensor in GPU
    device = torch.device('CUDA')
    x = torch.ones(5,device=device)
    
    #creating a tensor in CPU
    y = torch.ones(5)
    #moving it to GPU
    y =y.to(device)
    
    # Now the arithmetic will un in GPU  FASTER 
    z=x+y
    
    
    # If you want a numpy version , you have to move the varibale to CPU , Numpy cant support GPU
    res = z.to('cpu')
